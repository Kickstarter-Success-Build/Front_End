# %%
import pandas as pd

# %%
df = pd.read_csv('kickstarter.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              blurb       state
# 0           0  Using their own character, users go on educati...      failed
# 1           1  MicroFly is a quadcopter packed with WiFi, 6 s...  successful
# 2           2  A small indie press, run as a collective for a...      failed
# 3           3  Zylor is a new baby cosplayer! Back this kicks...      failed
# 4           4  Hatoful Boyfriend meet Skeletons! A comedy Dat...      failed

# %%
df['state'].value_counts(normalize=True)
# Out:
# failed        0.552048
# successful    0.447952
# Name: state, dtype: float64
